# %% [markdown]
# 1. System Expert
#     - Linux system
#         - User, permisions, groups and chmod
#         - Tarbal commands
#         - Service, process and memory related commands
#         - Creating a system service from some installation/code or .sh file
#     - Load Balancers (Ngnix, Apache, Elastic Load Balancer)
#     - Messaging Queue (Zookeeper-Kafka & RabbitMQ)
#         - Concepts & components- Broker, topic, partition, producer and consumer
#         - Setup zookeeper and Kafka (jvm requried)
#         - https://phoenixnap.com/kb/install-apache-zookeeper?
#         - Intall kafka-python
#         - Connection code
#         - Producer code
#         - Consumer code
#     - Caching (Memcached & Redis)
#         - Per-site cache- Middleware
#         - Per-view cache- Decorator
#         - Template fragment cache- {% cache 500 recipe %}
#         - Low-level cache API - get/set methods
#         - https://testdriven.io/blog/django-caching/
#         - https://www.honeybadger.io/blog/caching-in-django/
#     - Blob Storage (AWS-S3)
#     - Serverless (Lambda)
#     - AWS (IAM, AWS CLI, Boto3, EC2, S3, Lambda, RSD, ELB, SNS, STS, SQS, Kinesis)
#     - Logging & Monitoring (InfluxBD, Grafana, Newrelic & Kibana)
#     - Git and Gitlab
#     - Jenkins
#     - Docker
#     - Kubernates
#     - Microservices
#     - Monolith
#     - When to use monolith and when to use microservices
#     - High Level Design Examples- 20 or atleast 10 different types of products
#     - HLD Examples
#         - URL shortner
#         - Airbnb
#         - Youtube/Netflix
#         - Hotstar
#         - Google map
#         - Google drive/dropbox
#         - WhatsApp
#         - Uber
#         - Webcrawler
#         - Calendar
#         - Bookmyshow
#         - Newsfeed
#         - Notification System
#         - Rate limitor
#         - Typehead seerch
# 2. DSA Expert
#     - String & Array ( 100 Questions )
#     - Linkedlist ( 50 Questions )
#     - Stack, Queue, Hashmap ( 50 Questions)
#     - Binary Tree
# 3. Programing Expert
#     - Python
#         - List, dict, tuple, set
#         - Lambda, zip & map
#         - List & dict conprehension
#         - Iterators & Generators
#         - Range and xrange
#         - Decorators & Closures
#         - Collections-Counter,namedtuple,OrderedDict,DefaultDict,ChainMap,DeQue,UserDict,UserList,UserString
#         - OOPS- Class/Object, Inheritance, Polymorphism, Encapsulation, Abstration
#         - Singleton,Factory,Abstract Factory,Builder,Prototype,Adapter,Bridge,Facade,Decorator,Chain of Responsivility, Iterator, Observer
#         - Design methodologies- SOLID, Cohesion & Decoupling
#         - Metaclass
#         - Context Managers
#         - Input/Ouput and file handling
#         - Threading & Multiprocessing
#         - Numpy & Pandas
#         - Requests
#         - Pytest
#         - PyQt5
#     - JavaScript/TypeScript
#         - Working with arrays- forEach, map, filter, sort, reduce.
#         - Functions, scope, hoisting, IIFE
#         - Classes-Objects
#         - Destructuring arrays and objects, including for function arguments
#         - Callbacks
#         - Closures & Decorators
#         - OOPS in javascript
#         - asynchronous operations: promises, async/await syntax, fetch
#         - try / catch / throw
#         - this, bind/apply/call
#         - iterators/generators
#         - maps and sets
#         - web workers
#         - DOM API, canvas API, … all the browser APIs
#     - Java
#         - Write code to read a file line by line and do some processing
#         - Write multithreaded program to fetch location data, write the details in same file
#         - Write async task program which downloads some image and compress
#         - Write a program to connect to PostgreSQL database, write, read, edit and delete some data
# 4. Database Expert
#     - SQL quiries
#     - Indexing
#     - Sharding
#     - Replication
#     - MongoDB quireis
#     - Elasticsearch quiries
#     - Redis
# 5. Framwork Expert
#     - Django- Rest-Framework, ORM, Session, Middleware, Authentication, Security, Management Commands
#     - Flask- SQLAlchemy
#     - Fast API
#     - ReactJS
#     - Designing microservices with Django, Flask and FastAPI
# 6. Data & AI-ML Beginer
#     - Apache Spark
#     - Apache Kafka
#     - Casandra
#     - Hadoop
#     - Big Query
#     - Airflow
#     - Snowflake
#     - Redash
#     - PowerBI
#     - Scikit Learn
#     - Tensorflow
#     - Keras
#     - PyTorch
#     - https://www.edureka.co/blog/top-12-artificial-intelligence-tools/?
#     - NLTK
#     - textBlob
#     - SpaCy
#     - Baidu ERNIE
#     - Stanford CoreNLP
#     - https://odsc.medium.com/10-notable-frameworks-for-nlp-ce8c4196bfd6
